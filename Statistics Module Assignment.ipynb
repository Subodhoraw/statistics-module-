# %% [markdown]
# <a id='1'></a><center> <h3 style="background-color:orange; color:white" ><br>Telecommunication Industry Project<br></h3>

# %% [markdown]
# # Introduction
# This Jupyter notebook is part of your learning experience in the study of applied statistics.
#
# You will work with a data set that contains mobile phone prices and their specifications.
#
# **Dataset Columns Information**
#
# PID = a unique identifier for the phone model
#
# Blue = whether the phone has bluetooth support or not
#
# Wi_Fi = whether the phone has wifi support or not
#
# Tch_Scr = whether the phone has touch screen support or not
#
# Ext_Mem = whether the phone has external memory support or not
#
# Px_h = number of pixels in the vertical axis of the phone
#
# Px_w = number of pixels in the horizontal axis of the phone
#
# Scr_h = height of the screen of the phone in centimetres (cm)
#
# Scr_w = width of the screen of the phone in centimetres (cm)
#
# Int_Mem = internal memory of the phone measured in megabytes (MB)
#
# Bty_Pwr = maximum energy stored by the phone's battery measured in
# milli-Ampere-hours (mAh)
#
# PC = resolution of the primary camera measued in megapixels (MP)
#
# FC = resolution of the front camera measued in megapixels (MP)
#
# RAM = random access memory available in the phone measured in gigabytes (GB)
#
# Depth = depth of the mobile phone measured in centimetres (cm)
#
# Weight = weight of the mobile phone measured in grams (g)
#
# Price = selling price of the mobile phone in rupees

# %% [markdown]
# ## Task 1 - Load and study the data

# %% [markdown]
# Import the libraries that will be used in this notebook

# %%
# Load "numpy" and "pandas" for manipulating numbers and data frames
# Load "matplotlib.pyplot" and "seaborn" for data visualisation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the csv file as pandas dataframe.

# %%
# Read in the "Dataset" file as a Pandas Data Frame

data =pd.read_csv('Telecom Dataset.csv')

# %%
# Take a brief look at the data
data.head()
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 0  AAB346A  yes   yes      no      no   780   460      3      1   2   2
# 1  AAC347I  yes   yes      no      no   780   560      2      1   4   2
# 2  BAB657J   no   yes      no      no   840   720      2      1   4   2
# 3  BBD456K   no   yes     yes      no  1280  1120      5      3   6   2
# 4  CCP761U   no   yes     yes      no  1280  1080      4      3   6   2
#
#    Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price       Px     Scr_d  \
# 0        8     2800    2      7     320   3297   358800  3.162278
# 1        8     3000    2      7     280   4500   436800  2.236068
# 2        8     3300    2      7     400   4898   604800  2.236068
# 3       32     3000    2      3     300   6900  1433600  5.830952
# 4       16     3000    2      3     210   5600  1382400  5.000000
#
#    Scr_d_inches
# 0           1.2
# 1           0.9
# 2           0.9
# 3           2.3
# 4           2.0

# %%
# Get the dimensions of the dataframe
data.shape
# Out:
# (50, 20)

# %%
# Get the row names of the dataframe

data.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
# Get the column names of the dataframe
data.columns
print(data.columns.tolist())
# Out:
# ['PID', 'Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem', 'Px_h', 'Px_w', 'Scr_h', 'Scr_w', 'PC', 'FC', 'Int_Mem', 'Bty_Pwr', 'RAM', 'Depth', 'Weight', 'Price', 'Px', 'Scr_d', 'Scr_d_inches']

# %%
# Look at basic information about the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PID           50 non-null     object
#  1   Blue          50 non-null     object
#  2   Wi_Fi         50 non-null     object
#  3   Tch_Scr       50 non-null     object
#  4   Ext_Mem       50 non-null     object
#  5   Px_h          50 non-null     int64
#  6   Px_w          50 non-null     int64
#  7   Scr_h         50 non-null     int64
#  8   Scr_w         50 non-null     int64
#  9   PC            50 non-null     int64
#  10  FC            50 non-null     int64
#  11  Int_Mem       50 non-null     int64
#  12  Bty_Pwr       50 non-null     int64
#  13  RAM           50 non-null     int64
#  14  Depth         50 non-null     int64
#  15  Weight        50 non-null     int64
#  16  Price         50 non-null     int64
#  17  Px            50 non-null     int64
#  18  Scr_d         50 non-null     float64
#  19  Scr_d_inches  50 non-null     float64
# dtypes: float64(2), int64(13), object(5)
# memory usage: 7.9+ KB

# %% [markdown]
# Observations:
#
# There are 50 phones in the data set.
#
# There are 17 features in the data set including the "PID" feature which is used as the row index labels.
#
# There are no missing values in the data set.

# %% [markdown]
# <center>Let's try some logical operators to filter the data.<center>

# %% [markdown]
# ![](https://th.bing.com/th/id/R.0592084daa6518e4fae97f47217ec69e?rik=vNqmiaTVSSo54w&riu=http%3a%2f%2f2.bp.blogspot.com%2f-ujABms6N-Cg%2fTyYwShdTjnI%2fAAAAAAAAAAs%2fktPbHdifidc%2fs1600%2fLogical%2bOperators.PNG&ehk=ww1gl1HB2PcZwPQNHWRUvcQ631Q3mzyHSxL9G4zUKT4%3d&risl=&pid=ImgRaw&r=0,width=700,height=400)

# %% [markdown]
# ## Task 2 - Obtain the logical conditions for the features "Blue", "Wi_Fi", "Tch_Scr" and "Ext_Mem"

# %%
# Get the feature names of the dataframe
data.columns
# Out:
# Index(['PID', 'Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem', 'Px_h', 'Px_w', 'Scr_h',
#        'Scr_w', 'PC', 'FC', 'Int_Mem', 'Bty_Pwr', 'RAM', 'Depth', 'Weight',
#        'Price', 'Px', 'Scr_d', 'Scr_d_inches'],
#       dtype='object')

# %%
# Let's tackle these features: "Blue", "Wi_Fi", "Tch_Scr", "Ext_Mem"
#binary_features =["Wi_Fi","Tch_Scr","Ext_Mem"]
#for i, col in binary_features:
   # sns.countplot(data[col])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Added 'Blue' based on your comment
binary_features = ["Blue", "Wi_Fi", "Tch_Scr", "Ext_Mem"]

# Set up the figure size (width, height)
plt.figure(figsize=(15, 4)) 

for i, col in enumerate(binary_features):
    # Create a subplot: 1 row, 4 columns, index i+1
    plt.subplot(1, 4, i + 1)
    
    # Plot the count
    sns.countplot(x=data[col])
    
    # Add title and cleanup
    plt.title(col)
    plt.ylabel('Count')

plt.tight_layout() # Prevents overlapping labels
plt.show()

# %%
# The children want phones that have the following: Bluetooth, WiFi, touch screen and external memory support
# Create a logical condition for this situation and store the logical values as "con1"

#filtering for phones that all have the 4 features
children_choices = data[(data["Blue"]== 1)&
                        (data["Wi_Fi"] ==1)&
                        (data["Tch_Scr"]==1)&
                        (data["Ext_Mem"]==1)
                        ]
#check how many phones matching 
print(f"Number of phones matching criteria : {len(children_choices)}")

#View the first few matching phones
children_choices.head()

# Create the boolean mask (True/False series)
con1 = (data["Blue"] == 1) & (data["Wi_Fi"] == 1) & (data["Tch_Scr"] == 1) & (data["Ext_Mem"] == 1)

# Verify the result
print(con1.head())
# Out:
# Number of phones matching criteria : 0
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# Observations:
#
# The features "Blue", "Wi_Fi", "Tch_Scr" and "Ext_Mem" are binary in nature.
#
# The children want all these features, so the logical condition "con1" has been obtained accordingly.

# %% [markdown]
# ## Task 3 - Obtain the logical conditions for the features "Px_h" and "Px_w"

# %%
# Get the feature names of the dataframe
# Get the feature names
feature_names = data.columns

# Display them
print(feature_names)
# Out:
# Index(['PID', 'Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem', 'Px_h', 'Px_w', 'Scr_h',
#        'Scr_w', 'PC', 'FC', 'Int_Mem', 'Bty_Pwr', 'RAM', 'Depth', 'Weight',
#        'Price'],
#       dtype='object')

# %%
# Let's tackle these features: "Px_h", "Px_w"
binary_features = ["Px_h","Px_w"]
plt.figure(figsize= (15, 4))

for i, col in enumerate(binary_features):
    plt.subplot(1,2, i+1)

    #plt count
    sns.countplot(x = data[col])

    ## Add title and cleanup
    plt.title(col)
    plt.ylabel('count')
plt.tight_layout() # Prevents overlapping labels
plt.show()

# %%
# Create a new feature called "Px" which stores the total resolution of the screen

# Create a new feature 'Px' by multiplying pixel height and width
data['Px'] = data['Px_h'] * data['Px_w']

# Check the new column
print(data[['Px_h', 'Px_w', 'Px']].head())
# Save the updated dataframe to a new file
data.to_csv("Telecom Dataset.csv", index=False)

print("File saved successfully!")
# Out:
#    Px_h  Px_w       Px
# 0   780   460   358800
# 1   780   560   436800
# 2   840   720   604800
# 3  1280  1120  1433600
# 4  1280  1080  1382400
# File saved successfully!

# %%
# Create a histogram of the "Px" feature and also show the mean and the median
#sns.histplot(data = data, x = 'Px')
#print(data['Px'])

#1.calculate
px_mean = data['Px'].mean()
px_median = data['Px'].median()

#2. Setuop the figure
plt.figure(figsize =(10,6))

#3.Create the histogram
sns.histplot(data['Px'],kde = True, color ='skyblue')

#5. add Vertical lines formean and median
plt.axvline(px_mean, color ='red',linestyle = '--',linewidth =2,label =f'Mean:{px_mean:.0f}')
plt.axvline(px_median, color = 'green',linestyle = '-',linewidth =2, label = f'Median:{px_median: .0f}')

# %%
# The children want phones that have good screen resolutions
# Consider the phones that have screen resolutions greater than or equal to the median value in the data set
# Create a logical condition for this situation and store the logical values as "con2"

#filtering for phones that all have the 4 features
good_resolution = data['Px'].mean()
res_med = data['Px'].median()

#filtering data 
good_res_phone = data[data['Px'] >= good_resolution]

#check the results
print(f" The averages reolutions is :{good_resolution:.0f} pixels")
print(f" Number of phones with 'GOOD resolutions'{len(good_res_phone)}")

#View the top 5 entries
good_res_phone[['Px_h','Px_w','Px']].head(10)
print

# consider median as good res
good_res_phone2 = data[data['Px'] >= res_med]

#print good phone as median
print(f" good ress phone acc. median {res_med}")
print(f" Number of phones in good res: {len(good_res_phone2)}")

##view the to top 
good_res_phone2[['Px_h','Px_w','Px']].head()

# condition 2
con2 = (data['Px'] >= good_resolution) & (data['Px'] >= res_med)
print(con2.head())
# Out:
#  The averages reolutions is :4517184 pixels
#  Number of phones with 'GOOD resolutions'36
#  good ress phone acc. median 5108400.0
#  Number of phones in good res: 30
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Px, dtype: bool

# %% [markdown]
# Observations:
#
# The features "Px_h" and "Px_w" are respectively the number of pixels in the phone screen in the vertical and horizontal axes.
#
# We created a new feature called "Px" which is the product of the features "Px_h" and "Px_w".
#
# The median has been selected as a threshold in this case.
#
# In case it is too strict, we can choose the mean as a threshold.

# %% [markdown]
# # Task 4 - Obtain the logical conditions for the features "Scr_h" and "Scr_w"

# %%
# Let's tackle these features: "Scr_h", "Scr_w"
phone_features =['Scr_h','Scr_w']
#careting figure
plt.figure(figsize =(16, 9))

#creating  figure 
for i , col in enumerate(phone_features):

    plt.subplot(1,2, i+1)

    #countplot
    sns.countplot(x = data[col])
    # adding title
    plt.title(col)
    plt.ylabel('count')
plt.tight_layout()
plt.savefig('srch_scrw.jpg')

# %%
# Create a new feature called "Scr_d" which stores the length of the diagonal of the screen of the phone
data['Scr_d'] = np.sqrt(data['Scr_h']**2 + data['Scr_w']**2)
data['Scr_d_inches'] = (data['Scr_d'] / 2.54).round(1)
data.to_csv("Telecom Dataset.csv", index=False)
print(data[['Scr_d','Scr_w','Scr_h']].head())
# Out:
#       Scr_d  Scr_w  Scr_h
# 0  3.162278      1      3
# 1  2.236068      1      2
# 2  2.236068      1      2
# 3  5.830952      3      5
# 4  5.000000      3      4

# %%
# Create a histogram of the "Scr_d" feature and also show the quartiles
plt.figure(figsize = (16, 6) )
sns.histplot(data['Scr_d'], color= 'Red',kde= True)

#calculate the quartiles
Q1 = data['Scr_d'].quantile(.25) #25% quantile 
Q2 = data['Scr_d'].quantile(.50) #50%quantile
Q3 = data['Scr_d'].quantile(.75) #75% quantile 

#add verticle lines for Quartiles
plt.axvline(Q1, color ='Blue', linestyle ='--', label = f'Q1(25%):{Q1:.2f}')
plt.axvline(Q2, color ='green',linestyle ='-',linewidth = 2, label = f'Median (50%):{Q2:.2f}')
plt.axvline(Q3, color='purple', linestyle=':', linewidth=2, label=f'Q3(75%):{Q3:.2f}')
plt.axvspan(Q3, data['Scr_d'].max(), color='yellow', alpha=0.2, label='Above Q3')

#labels and legend 
plt.title('Distribution of Screen Duiagonal (inches)')
plt.xlabel('screen Sizes (Inches)')
plt.ylabel('Count')
plt.legend()
plt.show()

#quartile 
print(f"25% of phones are smaller than: {Q1} inches")
print(f"50% of phones are smaller than: {Q2} inches")
print(f"75% of phones are smaller than: {Q3} inches")
# Out:
# 25% of phones are smaller than: 5.830951894845301 inches
# 50% of phones are smaller than: 7.810249675906654 inches
# 75% of phones are smaller than: 10.0 inches

# %%
# The children want phones that have very good screen sizes
# Consider the phones that have screen sizes greater than or equal to the upper quartile value in the data set
# Create a logical condition for this situation and store the logical values as "con3"

# Use Q3 (already defined) as the threshold for "very good" screen size
con3 = data['Scr_d'] >= Q3

# Filter phones with very good screen sizes
very_good_scr_phone = data[con3]

# Display the first few matching phones
very_good_scr_phone[['PID', 'Scr_d', 'Scr_h', 'Scr_w']].head()
# Out:
#         PID      Scr_d  Scr_h  Scr_w
# 7   DFR256N  10.000000      8      6
# 11  ELS333L  10.000000      8      6
# 15  NSD450I  12.806248     10      8
# 16  PDF768G  10.000000      8      6
# 17  PDG234M  10.000000      8      6

# %% [markdown]
# Observations:
#
# The features "Scr_h" and "Scr_w" are respectively the height and the width of the phone screen.
#
# We created a new feature called "Scr_d" which is essentially the length of the screen diagonal.
#
# The upper quartile has been selected as a threshold in this case as the children were very particular on this point.
#
# In case it is too strict, we can choose the mean or the median as a threshold.

# %% [markdown]
# # Task 5 - Obtain the logical conditions for the features "PC" and "FC"

# %%
# Let's tackle these features: "PC", "FC"
camera_features = ['PC','FC']
plt.Figure(figsize = (10, 6))

for i, col in enumerate(camera_features):
    plt.subplot(1, 2, i +1)

    #crreate plot
    sns.countplot(x= data[col])

    #title
    plt.title('Camera Features primary and fornt ')
    plt.ylabel('count')
plt.tight_layout()

# %%
# Create a histogram of the "PC" feature and also show the mean and the median
plt.figure(figsize = (10, 7))
sns.histplot(data['PC'], kde = True, color = 'orange')

#calculate the mean and median
PC_mean = data['PC'].mean()
PC_median = data['PC'].median()

#display the vertical line 
plt.axvline(PC_mean, color = 'green',linestyle ='--', label = f'mean {PC_mean}')
plt.axvline(PC_median, color= 'yellow',linestyle = '-', label = f'median {PC_median}')

#header 
plt.title('Primary camera and its count')
plt.xlabel('Primary camera resolution' )
plt.ylabel('counts')
plt.legend()

# %%
# Create a histogram of the "FC" feature and also show the mean and the median
plt.figure(figsize = (10, 7))
sns.histplot(data['FC'], kde = True, color = 'orange')

#calculate the mean and median
Fc_mean = data['FC'].mean()
FC_median = data['FC'].median()

#display the vertical line 
plt.axvline(Fc_mean, color = 'green',linestyle ='--', label = f'mean {Fc_mean}')
plt.axvline(FC_median, color= 'yellow',linestyle = '-', label = f'median {FC_median}')

#header 
plt.title('front camera and its count')
plt.xlabel('front camera resolution' )
plt.ylabel('counts')
plt.legend()

# %%
# The children want phones that have good primary and front camera resolutions
# Consider the phones that have primary and front camera resolutions greater than or equal to their respective mean values
# Create a logical condition for this situation and store the logical values as "con4"

con4 = (data['PC'] >= PC_mean) & (data['FC'] >= Fc_mean)

# Filter phones with good camera
good_camera_phone = data[con4]

# Display the first few matching phones
good_camera_phone[['PID', 'PC', 'FC']].head()
# Out:
#         PID  PC  FC
# 9   ENG897N  64  32
# 11  ELS333L  64  32
# 12  ETT987D  64  32
# 16  PDF768G  64  32
# 21  QWR222Y  64  32

# %% [markdown]
# Observations:
#
# The features "PC" and "FC" are respectively the resolutions of the primary camera and the front camera.
#
# The respective means have been selected as thresholds in this case.
#
# In case it is too strict, we can choose the respective medians as thresholds.

# %% [markdown]
# # Task 6 - Obtain the logical conditions for the features "Int_Mem", "Bty_Pwr" and "RAM"

# %%
# Let's tackle these features: "Int_Mem", "Bty_Pwr", "RAM"
phone_features = ['Int_Mem', 'Bty_Pwr', 'RAM']
plt.figure(figsize=(18, 5))

for i, col in enumerate(phone_features):
    plt.subplot(1, 3, i + 1)
    sns.histplot(data[col], kde=True, color='skyblue')
    plt.title(col)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
# Create a histogram of the "Int_Mem" feature and also show the mean and the median
plt.figure(figsize = (10, 7))
sns.histplot(data['Int_Mem'], kde = True, color = 'orange')

#calculate the mean and median
Intmem_mean = data['Int_Mem'].mean()
Intmem_median = data['Int_Mem'].median()

#display the vertical line 
plt.axvline(Intmem_mean, color = 'green',linestyle ='--', label = f'mean {Intmem_mean}')
plt.axvline(Intmem_median, color= 'yellow',linestyle = '-', label = f'median {Intmem_median}')

#header 
plt.title('Internal memory and its count')
plt.xlabel('internal memory ' )
plt.ylabel('counts')
plt.legend()

# %%
# Create a histogram of the "Bty_Pwr" feature and also show the mean and the median

plt.figure(figsize = (10, 7))
sns.histplot(data['Bty_Pwr'], kde = True, color = 'orange')

#calculate the mean and median
Bty_Pwr_mean = data['Bty_Pwr'].mean()
Bty_Pwr_median = data['Bty_Pwr'].median()

#display the vertical line 
plt.axvline(Bty_Pwr_mean, color = 'green',linestyle ='--', label = f'mean {Bty_Pwr_mean}')
plt.axvline(Bty_Pwr_median, color= 'yellow',linestyle = '-', label = f'median {Bty_Pwr_median}')

#header 
plt.title('Batery power and its count')
plt.xlabel('Batery Mah ' )
plt.ylabel('counts')
plt.legend()

# %%
# Create a histogram of the "RAM" feature and also show the mean and the median

plt.figure(figsize = (10, 7))
sns.histplot(data['RAM'], kde = True, color = 'orange')

#calculate the mean and median
RAM_mean = data['RAM'].mean()
RAM_median = data['RAM'].median()

#display the vertical line 
plt.axvline(RAM_mean, color = 'green',linestyle ='--', label = f'mean {RAM_mean}')
plt.axvline(RAM_median, color= 'yellow',linestyle = '-', label = f'median {RAM_median}')

#header 
plt.title('Ram and its count')
plt.xlabel('Ram in GB ' )
plt.ylabel('counts')
plt.legend()

# %%
# The children want phones that have good internal memory, battery power and RAM
# Consider the phones that have internal memory, battery power and RAM greater than or equal to their respective mean values
# Create a logical condition for this situation and store the logical values as "con5" # Let's tackle these features: "Int_Mem", "Bty_Pwr", "RAM"

con5 = (data['RAM'] >=RAM_mean) & (data['Bty_Pwr'] >= Bty_Pwr_mean) & (data['Int_Mem'] >= Intmem_mean)

children_choices =data[con5]

#print the phone and choices 
children_choices[['PID','Bty_Pwr','RAM','Int_Mem']].head()
# Out:
#         PID  Bty_Pwr  RAM  Int_Mem
# 28  SSD000L     4200    8      512
# 29  SYL888P     5000    8      256
# 30  TVF078Y     4860    8      512
# 32  TYS938L     4860    8     1024
# 42  WZB298K     5600    8     1024

# %% [markdown]
# Observations
#
# The features "Int_Mem", "Bty_Pwr" and "RAM" are respectively the internal memory, battery power and RAM of the phones.
#
# The respective means have been selected as thresholds in this case.
#
# .In case it is too strict, we can choose the respective medians as thresholds

# %% [markdown]
# # Task 7 - Obtain the logical conditions for the features "Depth" and "Weight"

# %%
# Let's tackle these features: "Depth", "Weight"
feature_names = ['Depth','Weight']

plt.figure(figsize=(10,6))
for i, col in enumerate(feature_names):
    plt.subplot(1,2, i+1)

    sns.histplot(x = data[col], kde = True, color = 'green')
    #titling 
    plt.title(col)
    plt.xlabel(col)
plt.tight_layout()

# %%
# Create a histogram of the "Depth" feature and also show the mean and the median
Dep_mean = data['Depth'].mean()
Dep_median = data['Depth'].median()

#create plot
sns.histplot(data['Depth'], kde= True,  color= 'black')
#vertical line
plt.axvline(Dep_mean, color = 'yellow', linestyle = '--', label = f' depth mean {Dep_mean}')
plt.axvline(Dep_median, color = 'blue',linestyle = '-', label = f' median data{Dep_mean}')
# line
plt.title('depth of the phone')
plt.xlabel('Depth')
# Out:
# Text(0.5, 0, 'Depth')

# %%
# Create a histogram of the "Weight" feature and also show the mean and the median
Wei_mean = data['Weight'].mean()
Wei_median = data['Weight'].median()

#create plot
sns.histplot(data['Weight'], kde= True,  color= 'black')
#vertical line
plt.axvline(Wei_mean, color = 'yellow', linestyle = '--', label = f' depth mean {Wei_mean}')
plt.axvline(Wei_median, color = 'blue',linestyle = '-', label = f' median data{Wei_median}')
# line
plt.title('depth of the phone')
plt.xlabel('Weight')
# Out:
# Text(0.5, 0, 'Weight')

# %%
# The children want phones that are light weight and slim
# Consider the phones that have depth and weight less than or equal to the respective median values in the data set
# Create a logical condition for this situation and store the logical values as "con6"

con6 = (data['Weight'] >=Wei_median) & (data['Depth'] >= Dep_median)

children_choices =data[con6]

#print the phone and choices 
children_choices[['PID','Weight','Depth']].head()
# Out:
#        PID  Weight  Depth
# 0  AAB346A     320      7
# 1  AAC347I     280      7
# 2  BAB657J     400      7
# 3  BBD456K     300      3
# 4  CCP761U     210      3

# %% [markdown]
# Observations:
#
# The features "Depth" and "Weight" are respectively the depth of the phone and the weight of the phone.
#
# The respective medians have been selected as thresholds in this case.
#
# In case it is too strict, we can choose the respective means as thresholds.

# %% [markdown]
# # Task 8 - Subset the data based on all the logical conditions

# %%
# Subset the dataframe using all the logical conditions that have been stored
# Store the subset of the dataframe as a new dataframe called "df1"
df1 = data[con1 & con2 & con3 & con4 & con5 & con6]
len(df1)
print(f"len of the dataframe {len(df1)}")
# Out:
# len of the dataframe 0

# %%
# Get the dimensions of the dataframe

df1.shape
# Out:
# (0, 20)

# %%
# Sort the dataframe according to the "Price" feature in ascending order and display it
# Sort df1 by 'price_range' in ascending order (Low to High)
df1_sorted = df1.sort_values(by='Price', ascending=True)

# Display the result
print(df1_sorted.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Sort the dataframe according to the "Price" feature in ascending order and display it
#       2 # Sort df1 by 'price_range' in ascending order (Low to High)
# ----> 3 df1_sorted = df1.sort_values(by='Price', ascending=True)
#       5 # Display the result
#       6 print(df1_sorted.head())
#
# NameError: name 'df1' is not defined

# %% [markdown]
# Observations:
#
# Based on all the logical conditions obtained through analysis of the features, we are left with three phones.
#
# The most expensive of these phones is the "TYS938L" model and the least expensive is the "TVF078Y" model.
#
# We could let the children choose from these three phones as per their preferences.

# %% [markdown]
# # Task 9 - Study the variability of the features in the original data set

# %%
# Calculate the ratio of the standard deviation to the mean for all the numerical features in the dataframe
# Store these values in a new series wherein the rows are the features and the only column is the calculated ratio
# Name the series as "deviations"

# select only numerical columns(just in case there is text columns)
numerical_data = data.select_dtypes(include =['number'])

#2.calculate the ratio: Standard deviation
deviations = numerical_data.std()/numerical_data.mean()

#rename the series for clarity(optiona, but good practice)
deviations.name = "deviations"
#display the results
print(deviations) 

data.to_csv("Telecom Dataset.csv", index= False)
# Out:
# Px_h            0.257998
# Px_w            0.256226
# Scr_h           0.314293
# Scr_w           0.407624
# PC              0.715716
# FC              0.712184
# Int_Mem         1.506514
# Bty_Pwr         0.256368
# RAM             0.479075
# Depth           0.306072
# Weight          0.388121
# Price           0.740868
# Px              0.398680
# Scr_d           0.340469
# Scr_d_inches    0.336029
# Name: deviations, dtype: float64

# %%
# View the "deviations" series after sorting it in descending order

#1.sort the deviations for cleaner look 
deviations_sorted = deviations.sort_values(ascending = False)

#2. Setup the plot
plt.figure(figsize = (12, 6))

#3. create a bar chat 
sns.barplot(x = deviations_sorted.index, y = deviations_sorted.values, palette = 'viridis')

#4. add labels
plt.title('Features Volatility : Ratio of standard Deviation to mean')
plt.xlabel('Features')
plt.ylabel('Coefficient of Variation (STD/Mean)')
plt.xticks(rotation = 90)
plt.tight_layout()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_23724\2482373854.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = deviations_sorted.index, y = deviations_sorted.values, palette = 'viridis')

# %% [markdown]
# Observations:
#
# The ratio of the standard deviation to the mean of a feature normalises it in a way.
#
# This allows for comparison between multiple features.
#
# The most variable feature in the original data set is the internal memory of the phones.
#
# The least variable feature in the original data set is the number of screen pixels in the horizontal axis.
#
# Although most features don't seem so variable, the prices of the phones are quite variable.
#
# Feel free to investigate what could be the cause of this difference in variability.
#
# Note: We encourage you to extend this analysis further and see what else you can find.
#
# Note: Please refer to the official website of Python and its libraries for various Python documentations.

# %% [markdown]
# # Conclusion
# 1. We have used concepts of descriptive statistics to study and work with a data set that contains mobile phone specifications.
#
# 2. We were able to recommend three phone models to the client which she can then propose to her children.
